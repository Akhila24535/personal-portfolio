# %% [markdown]
# <a href="https://colab.research.google.com/github/Akhila24535/personal-portfolio/blob/main/personal%20website.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install flask pyngrok

from flask import Flask, request
from pyngrok import ngrok
from threading import Thread

app = Flask(__name__)

@app.route('/')
def portfolio():
    return '''
    <!DOCTYPE html>
    <html>
    <head>
        <title>My Portfolio</title>
        <style>
            body{
                font-family:Arial;
                margin:0;
                background:#f4f4f4;
            }
            header{
                background:#333;
                color:white;
                text-align:center;
                padding:30px;
            }
            section{
                padding:20px;
            }
            .card{
                background:white;
                padding:15px;
                margin:10px;
                border-radius:10px;
                box-shadow:0 0 5px gray;
            }
            form input, form textarea{
                width:100%;
                padding:10px;
                margin:5px 0;
            }
            button{
                background:blue;
                color:white;
                padding:10px;
                border:none;
                cursor:pointer;
            }
        </style>
    </head>
    <body>

    <header>
        <h1>Akhila Bagudam</h1>
        <h3>B.Tech CSE Student</h3>
    </header>

    <section>
        <div class="card">
            <h2>About Me</h2>
            <p>I am a Computer Science Engineering student passionate about Web Development, Python, Java and Cloud Computing.</p>
        </div>

        <div class="card">
            <h2>Skills</h2>
            <ul>
                <li>Python</li>
                <li>Java</li>
                <li>HTML</li>
                <li>CSS</li>
                <li>JavaScript</li>
                <li>SQL</li>
            </ul>
        </div>

        <div class="card">
            <h2>Projects</h2>
            <ul>
                <li>E-Commerce Website</li>
                <li>Gift Cart: Smart Coupon Management</li>
                <li>Portfolio Website</li>
            </ul>
        </div>

        <div class="card">
            <h2>Contact</h2>
            <form action="/submit" method="post">
                <input type="text" name="name" placeholder="Name" required>
                <input type="email" name="email" placeholder="Email" required>
                <textarea name="message" placeholder="Message"></textarea>
                <button type="submit">Send</button>
            </form>
        </div>
    </section>

    </body>
    </html>
    '''

@app.route('/submit', methods=['POST'])
def submit():
    name = request.form['name']
    email = request.form['email']
    message = request.form['message']

    return f'''
    <h2>Thank You {name}!</h2>
    <p>Email: {email}</p>
    <p>Message: {message}</p>
    <a href="/">Back to Portfolio</a>
    '''

def run():
    app.run()

Thread(target=run).start()

public_url = ngrok.connect(5000)
print("Portfolio Website Link:", public_url)
# Out:
# ...
#  * Serving Flask app '__main__'
#  * Debug mode: off
# Address already in use
# Port 5000 is in use by another program. Either identify and stop that program, or start the server with a different port.
# ERROR:pyngrok.process.ngrok:t=2026-06-10T14:25:50+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="authentication failed: Usage of ngrok requires a verified account and authtoken.\n\nSign up for an account: https://dashboard.ngrok.com/signup\nInstall your authtoken: https://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_4018\r\n"
# ---------------------------------------------------------------------------
# PyngrokNgrokError                         Traceback (most recent call last)
# /tmp/ipykernel_1185/642747442.py in <cell line: 0>()
#     117 Thread(target=run).start()
#     118
# --> 119 public_url = ngrok.connect(5000)
#     120 print("Portfolio Website Link:", public_url)
#
# ...
